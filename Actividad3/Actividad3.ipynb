# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df0= pd.read_csv('22dic.txt', skiprows=3, sep='\s+')
df= pd.read_csv('22jun.txt', skiprows=3, sep='\s+')

# %%
df0=df0[:-27]
df1=df0.drop(df0.index[[0,1]])

# %%
df=df[:-27]
df2=df.drop(df.index[[0,1]])

# %%
df2 = pd.DataFrame(df2)
df1 = pd.DataFrame(df1)

# %%
df1.head()
# Out:
#      PRES HGHT  TEMP  DWPT RELH  MIXR DRCT SKNT   THTA   THTE   THTV
# 2  1012.0    4  22.2  10.2   46  7.77  215    5  294.4  317.0  295.7
# 3  1007.0   45  23.6   6.6   33  6.10  205    6  296.2  314.3  297.2
# 4  1000.0  103  23.0   5.0   31  5.50  190    8  296.1  312.6  297.1
# 5   991.0  181  22.3   4.7   32  5.43  190   10  296.2  312.5  297.2
# 6   976.0  314  21.2   4.2   33  5.32  195   15  296.4  312.3  297.4

# %%
df1.tail()
# Out:
#      PRES   HGHT   TEMP   DWPT RELH  MIXR   DRCT   SKNT   THTA   THTE   THTV
# 96   27.5  24455  -55.3  -91.3    0  0.00     83     20  608.2  608.3  608.2
# 97   27.0  24573  -54.9  -91.0    0  0.00     80     20  612.7  612.7  612.7
# 98   25.0  25068  -53.0  -89.6    0  0.01     80     27  631.6  631.7  631.6
# 99   24.0  25330  -52.0  -88.9    0  0.01     75     21  641.9  642.0  641.9
# 100  23.7  25411  -51.7  -88.7    0  0.01  645.1  645.2  645.1    NaN    NaN

# %%
df2.head()
# Out:
#      PRES HGHT  TEMP  DWPT RELH  MIXR DRCT SKNT   THTA   THTE   THTV
# 2  1026.0    4  11.4   5.4   67  5.51   40    7  282.5  297.9  283.4
# 3  1009.0  143  12.4   2.4   50  4.53   30   14  284.8  297.8  285.6
# 4  1000.0  217  12.2   2.2   50  4.51   25   17  285.4  298.3  286.1
# 5   982.0  369  11.8   0.5   46  4.05   15   19  286.5  298.2  287.2
# 6   961.0  550  11.4  -1.6   40  3.55    3   17  287.8  298.3  288.4

# %%
df2.tail()
# Out:
#      PRES   HGHT   TEMP   DWPT RELH  MIXR   DRCT   SKNT   THTA   THTE   THTV
# 97   16.1  27890  -56.9  -92.9    0  0.00    238     19  703.5  703.6  703.5
# 98   16.0  27929  -56.9  -92.9    0  0.00    235     18  704.9  704.9  704.9
# 99   15.0  28338  -56.7  -92.7    0  0.00    245     19  718.5  718.6  718.6
# 100  14.0  28775  -56.5  -92.5    0  0.01    265     28  733.5  733.6  733.5
# 101  13.9  28821  -56.5  -92.5    0  0.01  735.1  735.1  735.1    NaN    NaN

# %%
df2.PRES=pd.to_numeric(df2.PRES, errors='raise', downcast=None)
df1.PRES=pd.to_numeric(df1.PRES, errors='raise', downcast=None)
df2.HGHT=pd.to_numeric(df2.HGHT, errors='raise', downcast=None)
df1.HGHT=pd.to_numeric(df1.HGHT, errors='raise', downcast=None)
df2.TEMP=pd.to_numeric(df2.TEMP, errors='raise', downcast=None)
df1.TEMP=pd.to_numeric(df1.TEMP, errors='raise', downcast=None)
df2.DWPT=pd.to_numeric(df2.DWPT, errors='raise', downcast=None)
df1.DWPT=pd.to_numeric(df1.DWPT, errors='raise', downcast=None)
df2.RELH=pd.to_numeric(df2.RELH, errors='raise', downcast=None)
df1.RELH=pd.to_numeric(df1.RELH, errors='raise', downcast=None)
df2.MIXR=pd.to_numeric(df2.MIXR, errors='raise', downcast=None)
df1.MIXR=pd.to_numeric(df1.MIXR, errors='raise', downcast=None)
df2.DRCT=pd.to_numeric(df2.DRCT, errors='raise', downcast=None)
df1.DRCT=pd.to_numeric(df1.DRCT, errors='raise', downcast=None)
df2.SKNT=pd.to_numeric(df2.SKNT, errors='raise', downcast=None)
df1.SKNT=pd.to_numeric(df1.SKNT, errors='raise', downcast=None)

# %%
df1.dtypes
# Out:
# PRES    float64
# HGHT      int64
# TEMP    float64
# DWPT    float64
# RELH      int64
# MIXR    float64
# DRCT    float64
# SKNT    float64
# THTA     object
# THTE     object
# THTV     object
# dtype: object

# %%
df2.dtypes
# Out:
# PRES    float64
# HGHT      int64
# TEMP    float64
# DWPT    float64
# RELH      int64
# MIXR    float64
# DRCT    float64
# SKNT    float64
# THTA     object
# THTE     object
# THTV     object
# dtype: object

# %%
# Gráfica de Presión vs Altitud 22 dic
y1_1=df1[['HGHT']]
x1_1=df1['PRES' ]
plt.plot(x1_1,y1_1, "orange")
plt.title("Variación de la Presión respecto de la Altitud-22/Dic/17")
plt.ylabel("Altitud (m)")
plt.xlabel("Presión (hPa)")
plt.grid(True)
plt.show()

# %%
# Gráfica de Presión vs Altitud 22 jun
y2_1=df2[['HGHT']]
x2_1=df2['PRES' ]
plt.plot(x2_1,y2_1, "firebrick")
plt.title("Variación de la Presión respecto de la Altitud-22/Jun/17")
plt.ylabel("Altitud (m)")
plt.xlabel("Presión (hPa)")
plt.grid(True)
plt.show()

# %%
# Gráfica de Temperatura vs Altitud 22 Dic
y1_2=df1[['HGHT']]
x1_2=df1[['TEMP' ]]
plt.plot(x1_2,y1_2, "cornflowerblue")
plt.title("Variación de la Temperatura respecto de la Altitud-22/Dic/17")
plt.ylabel("Altitud (m)")
plt.xlabel("Temperatura (°C)")
plt.grid(True)
plt.show()

# %%
# Gráfica de Temperatura vs Altitud 22 Jun
y2_2=df2[['HGHT']]
x2_2=df2['TEMP' ]
plt.plot(x2_2,y2_2)
plt.title("Variación de la Temperatura respecto de la Altitud-22/Jun/17")
plt.ylabel("Altitud (m)")
plt.xlabel("Temperatura (°C)")
plt.grid(True)
plt.show()

# %%
# Gráfica de Temperatura y Temperatura de rocío vs Altitud 22 Dic
x1_3=df1['TEMP']
x12_3=df1['DWPT']
y1_3=df1['HGHT']
plt.plot(x1,y,"darkorchid", label='TEMP')
plt.plot(x2,y,"m", label='DWPT')
plt.legend(loc='upper right')
plt.title("Variación de la Temperatura y Temperatura de rocío respecto de la Altitud-22/Dic/17")
plt.xlabel("Temperatura (°C)")
plt.ylabel("Altitud (m)")
plt.grid(True)
plt.show()

# %%
# Gráfica de Temperatura y Temperatura de rocío vs Altitud 22 Jun
x2_3=df2['TEMP']
x22_3=df2['DWPT']
y2_3=df2['HGHT']
plt.plot(x1,y,"lightcoral", label='TEMP')
plt.plot(x2,y,"palevioletred", label='DWPT')
plt.legend(loc='upper right')
plt.title("Variación de la Temperatura y Temperatura de rocío respecto de la Altitud-22/Jun/17")
plt.xlabel("Temperatura (°C)")
plt.ylabel("Altitud (m)")
plt.grid(True)
plt.show()

# %%
# Gráfica de la Rapidez de los vientos 22 Dic
g1_4=df1.dropna()
g1_4=g1_4[['SKNT']]
plt.plot(g1_4, "purple")
plt.title("Variación de Rapidez de los vientos-22/Dic/17")
plt.ylabel("Rapidez (nudos)")
plt.grid(True)
plt.show()

# %%
# Gráfica de la Rapidez de los vientos 22 Jun
g2_4=df2.dropna()
g2_4=g2_4[['SKNT']]
plt.plot(g2_4, "m")
plt.title("Variación de Rapidez de los vientos-22/Jun/17")
plt.ylabel("Rapidez (nudos)")
plt.grid(True)
plt.show()

# %%
# Gráfica de Humedad Relativa vs Altitud 22 Dic
y1_5=df1[['HGHT']]
x1_5=df1[['RELH' ]]
plt.plot(x1_5,y1_5)
plt.title("Variación de la Humedad Relativa respecto de la Altitud-22/Dic/17")
plt.ylabel("Altitud (m)")
plt.xlabel("Humedad Relativa (%)")
plt.grid(True)
plt.show()

# %%
# Gráfica de Humedad Relativa vs Altitud 22 Jun
y2_5=df2[['HGHT']]
x2_5=df2[['RELH' ]]
plt.plot(x2_5,y2_5)
plt.title("Variación de la Humedad Relativa respecto de la Altitud-22/Jun/17")
plt.ylabel("Altitud (m)")
plt.xlabel("Humedad Relativa (%)")
plt.grid(True)
plt.show()
