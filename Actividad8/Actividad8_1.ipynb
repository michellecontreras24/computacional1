# %%
from scipy import array

def VanDerPol (X,t=0):
    x=X[0]
    y=X[1]
    dx=X[1]
    dy= u*(1-X[0]*X[0])*X[1]-X[0]
    return array ([dx,dy])

# %%
#Gráfica de condiciones iniciales 1
import numpy as np
from scipy import arange
from numpy import loadtxt
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties

#Tiempo
t0=0
tmax=50
pastemps=0.01
t=arange(t0,tmax,pastemps)

#Mu
u=2.0

#Condiciones iniciales 1
x0=-3.0
y0=-3.0
#Solución de la ED
x,y=odeint(VanDerPol, (x0,y0),t).T

#Gráfica 1
% matplotlib inline
figure(1, figsize=(10, 6))

xlabel('x', fontsize=15)
ylabel('y', fontsize=15)
grid(True)
lw = 2
plt.ylim(-6,6)
plt.xlim (-6,6)

plot(x,y, 'b', linewidth=lw)

title('Phase Portrait of the unforced Van der Pol oscillator', fontsize=15)
savefig('CI1.png', dpi=100)

# %%
#Gráfica de condiciones iniciales 2
#Tiempo
t0=0
tmax=50
pastemps=0.01
t=arange(t0,tmax,pastemps)

#Mu
u=2.0

#Condiciones iniciales 
x0=5.5
y0=0.009
#Solución de la ED
x,y=odeint(VanDerPol, (x0,y0),t).T

#Gráfica 
% matplotlib inline
figure(1, figsize=(10, 6))

xlabel('x', fontsize=15)
ylabel('y', fontsize=15)
grid(True)
lw = 2
plt.ylim(-6,6)
plt.xlim (-6,6)

plot(x,y, 'b', linewidth=lw)

title('Phase Portrait of the unforced Van der Pol oscillator', fontsize=15)
savefig('CI2.png', dpi=100)

# %%
#Gráfica de condiciones iniciales 3
#Tiempo
t0=0
tmax=50
pastemps=0.01
t=arange(t0,tmax,pastemps)

#Mu
u=2.0

#Condiciones iniciales 
x0=-4.5
y0=3.7
#Solución de la ED
x,y=odeint(VanDerPol, (x0,y0),t).T

#Gráfica 
% matplotlib inline
figure(1, figsize=(10, 6))

xlabel('x', fontsize=15)
ylabel('y', fontsize=15)
grid(True)
lw = 2
plt.ylim(-6,6)
plt.xlim (-6,6)

plot(x,y, 'b', linewidth=lw)

title('Phase Portrait of the unforced Van der Pol oscillator', fontsize=15)
savefig('CI3.png', dpi=100)

# %%
#Gráfica de condiciones iniciales 4
#Tiempo
t0=0
tmax=50
pastemps=0.01
t=arange(t0,tmax,pastemps)

#Mu
u=2.0

#Condiciones iniciales 
x0=0.2
y0=0.3
#Solución de la ED
x,y=odeint(VanDerPol, (x0,y0),t).T

#Gráfica 
% matplotlib inline
figure(1, figsize=(10, 6))

xlabel('x', fontsize=15)
ylabel('y', fontsize=15)
grid(True)
lw = 2
plt.ylim(-6,6)
plt.xlim (-6,6)

plot(x,y, 'b', linewidth=lw)

title('Phase Portrait of the unforced Van der Pol oscillator', fontsize=15)
savefig('CI4.png', dpi=100)
